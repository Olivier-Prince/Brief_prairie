# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
print(car_data.head)
# Out:
# <bound method NDFrame.head of     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]>

# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
print(car_data.head(3))
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0

# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv",skiprows = 1)
print(car_data.head)
# Out:
# <bound method NDFrame.head of               ritz  2014   3.35   5.59  27000  Petrol  Dealer  Manual  0
# 0              sx4  2013   4.75   9.54  43000  Diesel  Dealer  Manual  0
# 1             ciaz  2017   7.25   9.85   6900  Petrol  Dealer  Manual  0
# 2          wagon r  2011   2.85   4.15   5200  Petrol  Dealer  Manual  0
# 3            swift  2014   4.60   6.87  42450  Diesel  Dealer  Manual  0
# 4    vitara brezza  2018   9.25   9.83   2071  Diesel  Dealer  Manual  0
# ..             ...   ...    ...    ...    ...     ...     ...     ... ..
# 295           city  2016   9.50  11.60  33988  Diesel  Dealer  Manual  0
# 296           brio  2015   4.00   5.90  60000  Petrol  Dealer  Manual  0
# 297           city  2009   3.35  11.00  87934  Petrol  Dealer  Manual  0
# 298           city  2017  11.50  12.50   9000  Diesel  Dealer  Manual  0
# 299           brio  2016   5.30   5.90   5464  Petrol  Dealer  Manual  0
#
# [300 rows x 9 columns]>

# %%
import matplotlib.pyplot as plt

X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]

plt.scatter(X,Y)
plt.show()

# %%
import pandas as pd
import seaborn as sns
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
sns.scatterplot(x = 'Year', y = 'Selling_Price', data = car_data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Selling_Price'>

# %%
import pandas as pd
import seaborn as sns
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
car_data.groupby('Fuel_Type').count()
sns.scatterplot(x = 'Fuel_Type', y = 'Selling_Price', data = car_data)
# Out:
# <AxesSubplot:xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
car_data['Year'].hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
car_data['Selling_Price'].hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
x = car_data["Year"]
y = car_data["Selling_Price"]
plt.bar(x,y)
# Out:
# <BarContainer object of 301 artists>

# %%
import pandas as pd
car_data = pd.read_csv("/home/olivier/buy_car/carData.csv")
car_data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()
print(df)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()
ax = sns.catplot(x='Year', y='Selling_Price', data=df)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

print(df['Selling_Price'])
print(type(df['Selling_Price']))
x=range(0,301)
plt.plot(x,df['Selling_Price'])
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

plt.plot(df['Year'],df['Selling_Price'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

sns.catplot(x='Kms_Driven', y='Fuel_Type', 
            data=df,
            kind='box',
            height=4, aspect=3.5)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

sns.relplot(data=df, x=df['Selling_Price'], y=df["Kms_Driven"], hue="Year")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

#sns.relplot(data=df, x=df['Selling_Price'], y=df["Kms_Driven"], hue="Year")
sns.relplot(data=df,x="Kms_Driven", y="Selling_Price",hue="Year")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

sns.relplot(data=df, x=df['Kms_Driven'], y=df["Selling_Price"], hue="Fuel_Type")
#sns.relplot(data=df,x="Kms_Driven", y="Selling_Price",hue="Fuel_Type")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()
#sns.relplot(data=df, x=df['Selling_Price'], y=df["Kms_Driven"], hue="Year")

with sns.axes_style('white'):
    sns.jointplot(x="Year", y="Selling_Price", data=df, kind='reg')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

g = sns.lmplot(x="Year", y="Selling_Price", col="Fuel_Type", data=df)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

g = sns.lmplot(x="Year",y="Selling_Price",data=df, line_kws={'color': 'red'})

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

x = df['Year']
y = df['Selling_Price']
plt.scatter(x, y, color='black') # Nuage de points
plt.plot(x, y, color = 'red')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

#engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
#dbConnection = engine.connect()
#df = pd.read_sql("select * from db_car.cardata", dbConnection);
#dbConnection.close()

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index = ['a', 'b', 'c'])
plts = plt.plot(df, marker = 'o')
plt.legend(plts, df.columns)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index = ['a', 'b', 'c'])
plts = plt.plot(df.T, marker = 'o')
plt.legend(plts, df.columns)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

plt.title("Nombre de voiture à la vente en fonction de l'ancienneté")
res = plt.hist(df['Year'],rwidth = 0.5, density= True)
plt.xlabel('Année')
plt.ylabel('Voiture disponible')
# Out:
# Text(0, 0.5, 'Voiture disponible')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns
import numpy as np
import timeit

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

XYear = df["Year"]
YPrix = df["Selling_Price"]

model= np.polyfit( XYear,YPrix,1)
predict = np.poly1d(model)
print('y = ax + b :', predict)
plt.scatter(XYear, YPrix, color='blue') # Nuage de points
plt.plot(XYear,predict(XYear),color='r') #la droite
print('Execution Time :', timeit.timeit())
# Out:
# y = ax + b :
# 0.4151 x - 831.2
# Execution Time : 0.00906019399917568

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns
import numpy as np

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

polynomialOrder = 1
xData = df["Year"]
yData = df["Selling_Price"]

fittedParameters = np.polyfit(xData, yData, polynomialOrder)
print('Slope:', fittedParameters[0], 'Intercept:', fittedParameters[1])

modelPredictions = np.polyval(fittedParameters, xData)
absError = modelPredictions - yData

plt.scatter(xData, yData, color='blue', label='Original data') # Nuage de points
plt.plot(xData, predict(xData), color='r', label='Fitted line') #la droite
plt.legend()

SE = np.square(absError) # squared errors
MSE = np.mean(SE) # mean squared errors
RMSE = np.sqrt(MSE) # Root Mean Squared Error, RMSE
Rsquared = 1.0 - (np.var(absError) / np.var(yData))
print('R-squared:', Rsquared)
print('Execution time :', timeit.timeit())
# Out:
# Slope: 0.4150916946355393 Intercept: -831.1789245913275
# R-squared: 0.05576256251112788
# Execution time : 0.016074598001068807

# %%
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns
import numpy as np
import timeit

# Connecting to MySQL server at localhost using PyMySQL DBAPI 

engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

x = df["Year"].values
y = df["Selling_Price"].values

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
plt.plot(x, y, 'o', label='Original data')
plt.plot(x, intercept + slope*x, 'r', label='Fitted line')
plt.legend()
plt.show()
print("Slope: %f    Intercept: %f" % (slope, intercept))
print("R-squared: %f" % r_value**2)
print('Execution Time :', timeit.timeit())
# Out:
# Slope: 0.415092    Intercept: -831.178925
# R-squared: 0.055763
# Execution Time : 0.009758111002156511

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import seaborn as sns
import numpy as np
import timeit

# Connecting to MySQL server at localhost using PyMySQL DBAPI 
engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

# We're splitting up our data set into groups called 'train' and 'test'
x = df['Year'].values
X = x[:,np.newaxis]
y = df['Selling_Price'].values

# set up our model
linear = LinearRegression(fit_intercept = True)

# train the model 
linear.fit(X, y)

# Make predictions using the testing set
y_pred = linear.predict(X)

# Plot outputs
plt.scatter(X, y,  color='blue')
plt.plot(X,y_pred, color='red')

plt.xlabel('Year') # set the labels of the x and y axes
plt.ylabel('Selling_Price (lakhs)')
plt.show()

# The coefficients
print("Slope: %f    Intercept: %f" % (linear.coef_, linear.intercept_))

# The coefficient of determination: 1 is perfect prediction
print('R-squared : %.6f'
      % r2_score(y, y_pred))

print('Execution Time :', timeit.timeit())
# Out:
# Slope: 0.415092    Intercept: -831.178925
# R-squared : 0.055763
# Execution Time : 0.01000518699947861

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
from sklearn import linear_model
import timeit

# Connecting to MySQL server at localhost using PyMySQL DBAPI 
engine = create_engine("mysql+pymysql://olivier:Belair#3103@localhost/db_car")
dbConnection = engine.connect()
df = pd.read_sql("select * from db_car.cardata", dbConnection);
dbConnection.close()

df.head()

# We're splitting up our data set into groups called 'train' and 'test'
x = df['Year'].values
X = x[:,np.newaxis]
y = df['Selling_Price'].values

# On fit le modele
model = linear_model.LinearRegression()
results = model.fit(X, y)

# Coefficients
print("Slope: %f    Intercept: %f" % (results.coef_, results.intercept_))

# The coefficient of determination: 1 is perfect prediction
print('R-squared : %.6f'
      % r2_score(y, model.predict(X)))

print('Execution Time :', timeit.timeit())
# Out:
# Slope: 0.415092    Intercept: -831.178925
# R-squared : 0.055763
# Execution Time : 0.01521887700073421
